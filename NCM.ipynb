# %%
#pip install requests
#pip install TIME-python
#pip install beautifulsoup4
#pip install pandas
#pip install -U selenium
#pip install pyautogui

#IMPORTAR BIBLIOTECAS NECESSÁRIAS

import requests
import time
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver
from selenium.webdriver.edge.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as ec
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.common.exceptions import NoSuchElementException
import pyautogui as py

#ESTRUTURA DO ARRAY

#PEGA URL DOS SITES
url1 = "https://www.consultancm.com.br/"
url2 = "https://www.freenfe.com.br/consulta-ncm/"
url3 = "https://cosmos.bluesoft.com.br/ncms"
url3_aux = url3

#CONFIGURA REQUISIÇÃO

executable_path="msedgedriver.exe"
option = Options()
option.headless = False
driver = webdriver.Edge(options=option)

#LÊ ARQUIVO EXCEL

array2 = []
df = pd.read_excel("NCM.xlsx",0,index_col=0,header=None)
print(df)
array = df.to_records()
print(array)

#FAZ A REQUISIÇÃO

driver.get(url3)
#driver.minimize_window()
time.sleep(3)

#CLICA NA BARRA DE PESQUISA 
print(len(array))
print(array)
i=0
for i in range(10):#len(array)

    #element = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div/div/div/form/div/input') - url1
    #element = WebDriverWait(driver, 10).until(ec.presence_of_element_located((By.XPATH, "/html/body/div[1]/div/div/div[2]/div[1]/div/div[2]/div/div/form/input"))) # - url2
    #element = driver.find_element(By.XPATH, "/html/body/div[1]/div/div/div[2]/div[1]/div/div[2]/div/div/form/input") # - url2
    codigo = str(array[i])
    codigo = codigo.replace(",","")
    codigo = codigo.replace(")","")
    codigo = codigo.replace("(","")
    if(int(codigo)<10000000) : codigo='0'+codigo
    print(codigo)

#DIGITA O NCM


    #element.send_keys(codigo)
    url3_aux = url3
    url3_aux += "/"+str(codigo) 
    driver.get(url3_aux)


#PESQUISA 
    #element = driver.find_element(By.XPATH, "/html/body/div[1]/div/div/div/div/div/form/div/button[1]") - url1
    #element = WebDriverWait(driver, 10).until(ec.element_to_be_clickable((By.XPATH, "/html/body/div[1]/div/div/div[2]/div[1]/div/div[2]/div/div/form/button"))) # - url2
    #element = driver.find_element(By.XPATH, "/html/body/div[1]/div/div/div[2]/div[1]/div/div[2]/div/div/form/button") # - url2
    #element.send_keys(Keys.ENTER)
    #element.click()


#PEGA RESULTADO NO HTML

    #element = WebDriverWait(driver, 10).until(ec.presence_of_element_located((By.XPATH, "/html/body/div[1]/div/div/div/section[1]/div/div[1]/div/div/div/div"))) - url1
    #element = driver.find_element(By.XPATH, "/html/body/div[1]/div/div/div/section[1]/div/div[1]/div/div/div/div") - url1
    #element = WebDriverWait(driver, 10).until(ec.presence_of_element_located((By.XPATH, "/html/body/div[1]/div/div/div[2]/div[2]/div/div/div[3]/table/tbody/tr/td[3]/div")))# - url2
    #element = driver.find_element(By.XPATH, "/html/body/div[1]/div/div/div[2]/div[2]/div/div/div[3]/table/tbody/tr/td[3]/div") # - url2
    #element = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div/div/div/form/div/input') - url1
    #element = WebDriverWait(driver, 10).until(ec.presence_of_element_located((By.XPATH, "/html/body/div[1]/div/div/div[2]/div[1]/div/div[2]/div/div/form/input"))) # - url2
    #element = driver.find_element(By.XPATH, "/html/body/div[1]/div/div/div[2]/div[1]/div/div[2]/div/div/form/input") # - url2
    element = WebDriverWait(driver, 10).until(ec.presence_of_element_located((By.XPATH, "/html/body/div[3]/section/div[1]/div[2]/div[2]"))) # - url3
    element = driver.find_element(By.XPATH, "/html/body/div[3]/section/div[1]/div[2]/div[2]") # - url3
    descricao = element.text
#ALIMENTA ARRAY COM CÓDIGO E DESCRIÇÃO

    descricao = descricao[13 : ]
    print(descricao)
    array2.append(descricao)

#PESQUISA DE NOVO

    #element.clear()



#FECHA CONEXÂO

excel_array = pd.DataFrame(array2).T
excel_array.to_excel(excel_writer = "test.xlsx")

driver.quit()
# Out:
# Empty DataFrame
# Columns: []
# Index: [1012100, 1012900, 1013000, 1019000, 1022110, 1022190, 1022911, 1022919, 1022990, 1023110, 1023190, 1023911, 1023919, 1023990, 1029000, 1031000, 1039100, 1039200, 1041011, 1041019, 1041090, 1042010, 1042090, 1051110, 1051190, 1051200, 1051300, 1051400, 1051500, 1059400, 1059900, 1061100, 1061200, 1061300, 1061400, 1061900, 1062000, 1063100, 1063200, 1063310, 1063390, 1063900, 1064100, 1064900, 1069000, 2011000, 2012010, 2012020, 2012090, 2013000, 2021000, 2022010, 2022020, 2022090, 2023000, 2031100, 2031200, 2031900, 2032100, 2032200, 2032900, 2041000, 2042100, 2042200, 2042300, 2043000, 2044100, 2044200, 2044300, 2045000, 2050000, 2061000, 2062100, 2062200, 2062910, 2062990, 2063000, 2064100, 2064900, 2068000, 2069000, 2071100, 2071200, 2071300, 2071400, 2072400, 2072500, 2072600, 2072700, 2074100, 2074200, 2074300, 2074400, 2074500, 2075100, 2075200, 2075300, 2075400, 2075500, 2076000, ...]
#
# [10441 rows x 0 columns]
# ...
